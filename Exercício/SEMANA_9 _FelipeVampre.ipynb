# %% [markdown]
# # Semana 9 — SQL para Data Warehouse
#
# Nesta semana, vamos sair da etapa de construção do modelo dimensional e usar o Star Schema para responder perguntas de BI com SQL.
#
# ## Objetivos da Semana 9
#
# Ao final das 3 aulas, você deverá conseguir:
#
# - Usar `SELECT`, `WHERE` e `ORDER BY` em consultas analíticas.
# - Fazer `INNER JOIN` entre tabela fato e dimensões.
# - Usar `LEFT JOIN` para investigar ausência de relacionamento.
# - Criar métricas com `GROUP BY`, `SUM`, `COUNT` e `AVG`.
# - Filtrar agregações com `HAVING`.
# - Usar funções de data como `DATE_TRUNC` e `EXTRACT`.

# %% [markdown]
# ## Aula 1 da Semana 9 — SQL básico em DW
#
# ### Roteiro teórico
#
# Em um Data Warehouse, o SQL é usado principalmente para análise.
# Diferente de um sistema transacional, onde o foco é inserir e atualizar registros, aqui o foco é consultar, agregar e transformar dados em indicadores.
#
# A estrutura básica de uma consulta é:
#
# ```sql
# SELECT colunas
# FROM tabela
# WHERE condição
# ORDER BY coluna;
# ```
#
# No nosso modelo:
#
# - `fato_vendas` guarda os eventos mensuráveis de venda.
# - `dim_cliente` explica quem comprou e onde.
# - `dim_produto` explica o que foi vendido.
# - `dim_tempo` permite analisar a venda no tempo.

# %% [markdown]
# ### Ler dados dimensão e fato

# %%
### Importar pacotes

import pandas as pd
import duckdb

# %%
dim_cliente = pd.read_csv('../Dataset_schema/dim_cliente.csv')
dim_produto = pd.read_csv('../Dataset_schema/dim_produto.csv')
dim_tempo = pd.read_csv('../Dataset_schema/dim_tempo.csv')
fato_vendas = pd.read_csv('../Dataset_schema/fato_vendas.csv')

# %%
banco_dados = duckdb.connect()
banco_dados.register('dim_cliente', dim_cliente) # registra a dimensão cliente no banco de dados
banco_dados.register('dim_produto', dim_produto) # registra a dimensão produto no banco de dados
banco_dados.register('dim_tempo', dim_tempo) # registra a dimensão tempo no banco de dados
banco_dados.register('fato_vendas', fato_vendas) # registra a tabela fato vendas no banco de dados

# %% [markdown]
# ## Consulta exemplo — Faturamento total

# %%
banco_dados.sql("""
SELECT SUM(valor_total) AS faturamento_total
FROM fato_vendas
""").df() # consulta para calcular o faturamento total da loja, somando a coluna valor_total da tabela fato_vendas
# Out:
#    faturamento_total
# 0       1.541977e+07

# %% [markdown]
# ### Exemplo — selecionando vendas da fato

# %%
banco_dados.sql("""
SELECT
    venda_sk,
    order_id,
    valor_produto,
    valor_frete,
    valor_total
FROM fato_vendas
LIMIT 20
""").df()
# Out:
#     venda_sk                          order_id  valor_produto  valor_frete  \
# 0          1  00010242fe8c5a6d1ba2dd792cb16214          58.90        13.29
# 1          2  00018f77f2f0320c557190d7a144bdd3         239.90        19.93
# 2          3  000229ec398224ef6ca0657da4fc703e         199.00        17.87
# 3          4  00024acbcdf0a6daa1e931b038114c75          12.99        12.79
# 4          5  00042b26cf59d7ce69dfabb4e55b4fd9         199.90        18.14
# 5          6  00048cc3ae777c65dbb7d2a0634bc1ea          21.90        12.69
# 6          7  00054e8431b9d7675808bcb819fb4a32          19.90        11.85
# 7          8  000576fe39319847cbb9d288c5617fa6         810.00        70.75
# 8          9  0005a1a1728c9d785b8e2b08b904576c         145.95        11.65
# 9         10  0005f50442cb953dcd1d21e1fb923495          53.99        11.40
# 10        11  00061f2a7bc09da83e415a52dc8a4af1          59.99         8.88
# 11        12  00063b381e2406b52ad429470734ebd5          45.00        12.98
# 12        13  0006ec9db01a64e59a68b2c340bf65a7          74.00        23.32
# 13        14  0008288aa423d2a3f00fcb17cd7d8719          49.90        13.37
# 14        15  0008288aa423d2a3f00fcb17cd7d8719          49.90        13.37
# 15        16  0009792311464db532ff765bf7b182ae          99.90        27.65
# 16        17  0009c9a17f916a706d71784483a5d643         639.00        11.34
# 17        18  000aed2e25dbad2f9ddb70584c5a2ded         144.00         8.77
# 18        19  000c3e6612759851cc3cbb4b83257986          99.00        13.71
# 19        20  000e562887b1f2006d75e0be9558292e          25.00        16.11
#
#     valor_total
# 0         72.19
# 1        259.83
# 2        216.87
# 3         25.78
# 4        218.04
# 5         34.59
# 6         31.75
# 7        880.75
# 8        157.60
# 9         65.39
# 10        68.87
# 11        57.98
# 12        97.32
# 13        63.27
# 14        63.27
# 15       127.55
# 16       650.34
# 17       152.77
# 18       112.71
# 19        41.11

# %% [markdown]
# ### Exemplo — usando `WHERE` e `ORDER BY`
#
# A consulta abaixo busca vendas com valor total maior que 200 e ordena da maior para a menor.

# %%
banco_dados.sql("""
SELECT
    venda_sk,
    order_id,
    valor_produto,
    valor_frete,
    valor_total
FROM fato_vendas
WHERE valor_total > 100
ORDER BY valor_total ASC
""").df()
# Out:
#        venda_sk                          order_id  valor_produto  valor_frete  \
# 0         71991  a7bc4bc04f601abb381b240812701777          69.99        30.02
# 1         30561  46e986bd2d3cdddfbc642749d67b4777          75.00        25.02
# 2         92983  d77c5cb217e302146127b857e56ee27e          75.00        25.02
# 3         43797  65d20cd74349cb427d7feec3567a6fd0          89.99        10.04
# 4         43798  65d20cd74349cb427d7feec3567a6fd0          89.99        10.04
# ...         ...                               ...            ...          ...
# 50665     10998  199af31afc78c699f0dbf71fb178d4d4        4690.00        74.34
# 50666     72721  a96610ab360d42a2e5335a3998b4718a        4799.00       151.34
# 50667    105496  f5136e38d1a14a4dbd87dff67da82701        6499.00       227.66
# 50668    109785  fefacc66af859508bf1a7934eab1e97f        6729.00       193.21
# 50669      3482  0812eb902a67711a1cb742b3cdaa65ae        6735.00       194.31
#
#        valor_total
# 0           100.01
# 1           100.02
# 2           100.02
# 3           100.03
# 4           100.03
# ...            ...
# 50665      4764.34
# 50666      4950.34
# 50667      6726.66
# 50668      6922.21
# 50669      6929.31
#
# [50670 rows x 5 columns]

# %% [markdown]
# ## Exercício 13 🟢 Fácil — SELECT em tabela fato
#
# Liste as colunas `venda_sk`, `order_id`, `valor_produto`, `valor_frete` e `valor_total` das 15 primeiras vendas.

# %%
banco_dados.sql("""
    SELECT
        venda_sk,
        order_id,
        valor_produto,
        valor_frete,
        valor_total
    FROM fato_vendas
    LIMIT 15
""").df()
# Out:
#     venda_sk                          order_id  valor_produto  valor_frete  \
# 0          1  00010242fe8c5a6d1ba2dd792cb16214          58.90        13.29
# 1          2  00018f77f2f0320c557190d7a144bdd3         239.90        19.93
# 2          3  000229ec398224ef6ca0657da4fc703e         199.00        17.87
# 3          4  00024acbcdf0a6daa1e931b038114c75          12.99        12.79
# 4          5  00042b26cf59d7ce69dfabb4e55b4fd9         199.90        18.14
# 5          6  00048cc3ae777c65dbb7d2a0634bc1ea          21.90        12.69
# 6          7  00054e8431b9d7675808bcb819fb4a32          19.90        11.85
# 7          8  000576fe39319847cbb9d288c5617fa6         810.00        70.75
# 8          9  0005a1a1728c9d785b8e2b08b904576c         145.95        11.65
# 9         10  0005f50442cb953dcd1d21e1fb923495          53.99        11.40
# 10        11  00061f2a7bc09da83e415a52dc8a4af1          59.99         8.88
# 11        12  00063b381e2406b52ad429470734ebd5          45.00        12.98
# 12        13  0006ec9db01a64e59a68b2c340bf65a7          74.00        23.32
# 13        14  0008288aa423d2a3f00fcb17cd7d8719          49.90        13.37
# 14        15  0008288aa423d2a3f00fcb17cd7d8719          49.90        13.37
#
#     valor_total
# 0         72.19
# 1        259.83
# 2        216.87
# 3         25.78
# 4        218.04
# 5         34.59
# 6         31.75
# 7        880.75
# 8        157.60
# 9         65.39
# 10        68.87
# 11        57.98
# 12        97.32
# 13        63.27
# 14        63.27

# %% [markdown]
# ## Exercício 14 🟢 Fácil — Filtro com WHERE
#
# Liste as vendas cujo `valor_frete` seja maior que 50.
# Mostre `venda_sk`, `order_id`, `valor_frete` e `valor_total`.

# %%
banco_dados.sql("""
    SELECT
        venda_sk,
        order_id,
        valor_produto,
        valor_frete,
        valor_total
    FROM fato_vendas
    WHERE valor_frete > 50
""").df()
# Out:
#       venda_sk                          order_id  valor_produto  valor_frete  \
# 0            8  000576fe39319847cbb9d288c5617fa6         810.00        70.75
# 1           74  002b430ff89b3a24c31a1170acbbedea         199.99        65.56
# 2           83  0030ff924c38549807645976adeef2c0         225.00        67.24
# 3           97  0036757472ece3dde52fd4bfd929c90e         136.99        66.04
# 4          109  003edccf16bc5ec447f592913b3df2b4          14.00        50.85
# ...        ...                               ...            ...          ...
# 4454    109909  ff3e501f56dcf0752578d86df833558f         299.90       170.11
# 4455    109998  ff85f6534f8a6b89e27a340dcf86ecac         259.99        84.52
# 4456    110020  ff96d596c25445650eee60b94fa62244         329.00       127.55
# 4457    110101  ffc2638415f3ce34e88641eef792c1fc         629.00        67.08
# 4458    110161  ffebd80e3291e811c308365936897efd         129.90        51.20
#
#       valor_total
# 0          880.75
# 1          265.55
# 2          292.24
# 3          203.03
# 4           64.85
# ...           ...
# 4454       470.01
# 4455       344.51
# 4456       456.55
# 4457       696.08
# 4458       181.10
#
# [4459 rows x 5 columns]

# %% [markdown]
# ## Exercício 15 🟡 Médio — Ordenação para ranking
#
# Liste as 20 vendas de maior `valor_total`.
# Mostre `venda_sk`, `order_id`, `valor_produto`, `valor_frete` e `valor_total`.

# %%
banco_dados.sql("""
    SELECT
        venda_sk,
        order_id,
        valor_produto,
        valor_frete,
        valor_total
    FROM fato_vendas
    ORDER BY valor_total DESC
    LIMIT 20
""").df()
# Out:
#     venda_sk                          order_id  valor_produto  valor_frete  \
# 0       3482  0812eb902a67711a1cb742b3cdaa65ae        6735.00       194.31
# 1     109785  fefacc66af859508bf1a7934eab1e97f        6729.00       193.21
# 2     105496  f5136e38d1a14a4dbd87dff67da82701        6499.00       227.66
# 3      72721  a96610ab360d42a2e5335a3998b4718a        4799.00       151.34
# 4      10998  199af31afc78c699f0dbf71fb178d4d4        4690.00        74.34
# 5      60712  8dbc85d1447242f3b127dda390d56e19        4590.00        91.78
# 6      28537  426a9742b533fc6fed17d1fd6d143d7e        4399.87       113.45
# 7      55421  80dfedb6d17bf23539beeef3c768f4d7        3999.00       195.76
# 8      44822  68101694e5c5dc7330c91e1bbc36214f        4099.99        75.27
# 9      76618  b239ca7cd485940b31882363b52e6674        4059.00       104.51
# 10     65979  9a3966c23190dbdbaabed08e8429c006        3980.00        62.74
# 11     67630  9de73f3e6157169ad6c32b9f313c7dcb        3899.00       135.44
# 12     57838  86c4eab1571921a6a6e248ed312f5a5a        3999.90        17.01
# 13     28236  41b7766bb1df487d17fb9725b78ff509        3930.00        49.55
# 14     70871  a53e05ecd2ed1f46a2b8e1f5828be7c6        3690.00       136.80
# 15     91502  d3f66901a6743e15f9311547cc623b91        3700.00        92.59
# 16    100134  e85c92ee6a3ba1ef47e41c23286314d9        3699.99        36.23
# 17     96438  df85c824523500d4066a0dbdb5d95bed        3549.00        53.47
# 18     25064  3a4b013e014723cc38c9faa8ffdc6387        3399.99       126.47
# 19     29114  43bdbd9dc0931d72befdf4765af6c442        3089.00       317.47
#
#     valor_total
# 0       6929.31
# 1       6922.21
# 2       6726.66
# 3       4950.34
# 4       4764.34
# 5       4681.78
# 6       4513.32
# 7       4194.76
# 8       4175.26
# 9       4163.51
# 10      4042.74
# 11      4034.44
# 12      4016.91
# 13      3979.55
# 14      3826.80
# 15      3792.59
# 16      3736.22
# 17      3602.47
# 18      3526.46
# 19      3406.47

# %% [markdown]
# ##  JOINS em Star Schema
#
# ### Roteiro teórico
#
# Em um Star Schema, normalmente a análise começa na tabela fato e depois se conecta às dimensões.
#
# Exemplo de raciocínio:
#
# > Quero faturamento por estado.
# > O faturamento está na `fato_vendas`.
# > O estado está na `dim_cliente`.
# > Então preciso fazer JOIN entre fato e dimensão cliente.
#
# Tipos importantes:
#
# - `INNER JOIN`: retorna apenas registros que possuem correspondência nos dois lados.
# - `LEFT JOIN`: mantém todos os registros da tabela da esquerda, mesmo sem correspondência na direita.

# %% [markdown]
# ### Exemplo — fato + dimensão cliente

# %%
banco_dados.sql("""
SELECT
    f.venda_sk,
    f.order_id,
    f.valor_total,
    c.customer_state
FROM fato_vendas f
INNER JOIN dim_cliente c
    ON f.cliente_sk = c.cliente_sk
LIMIT 10
""").df()
# Out:
#    venda_sk                          order_id  valor_total customer_state
# 0    102401  edc438144eedf58c321995efd0225e19        68.45             GO
# 1    102402  edc531c3153d23614049077e7e1e6405       136.40             MG
# 2    102403  edc577111e3237868aec11a4da6611d9        61.58             MG
# 3    102404  edc5c94770796f4212d272830dd17840        42.58             SP
# 4    102405  edc6d3b93ee7050db4013694b93176ae        30.86             SP
# 5    102406  edc7444663af179dd113423c0512b4e4        67.98             SP
# 6    102407  edc75396403e226e7ac4e42085860602       185.93             CE
# 7    102408  edc852e0d271566f7923b10c089c30ec       133.42             RS
# 8    102409  edc89efa4164df7e21f701a9fb88bc98        55.15             SP
# 9    102410  edc89efa4164df7e21f701a9fb88bc98        73.00             SP

# %% [markdown]
# ### Exemplo — fato + dimensão produto + dimensão tempo

# %%
banco_dados.sql("""
SELECT
    f.venda_sk,
    f.order_id,
    p.product_category_name_english AS categoria,
    t.ano_mes,
    f.valor_total,
    c.customer_state AS estado
FROM fato_vendas f
INNER JOIN dim_produto p
    ON f.produto_sk = p.produto_sk
INNER JOIN dim_tempo t
    ON f.tempo_sk = t.tempo_sk
INNER JOIN dim_cliente c
    ON f.cliente_sk = c.cliente_sk
LIMIT 20
""").df()
# Out:
#     venda_sk                          order_id  \
# 0     102401  edc438144eedf58c321995efd0225e19
# 1     102402  edc531c3153d23614049077e7e1e6405
# 2     102403  edc577111e3237868aec11a4da6611d9
# 3     102404  edc5c94770796f4212d272830dd17840
# 4     102405  edc6d3b93ee7050db4013694b93176ae
# 5     102406  edc7444663af179dd113423c0512b4e4
# 6     102407  edc75396403e226e7ac4e42085860602
# 7     102408  edc852e0d271566f7923b10c089c30ec
# 8     102409  edc89efa4164df7e21f701a9fb88bc98
# 9     102410  edc89efa4164df7e21f701a9fb88bc98
# 10    102411  edc89efa4164df7e21f701a9fb88bc98
# 11    102412  edc89efa4164df7e21f701a9fb88bc98
# 12    102413  edc8ed56158af55c22d0d8153e921879
# 13    102414  edc9338008f2e9017f842a8bcad3af94
# 14    102415  edc9fcd5f5ab3aa69901aa991026ee0c
# 15    102416  edca1e6e5049a09e73c18ba943979a84
# 16    102417  edcaded448abfc7302a12be6f10cbdec
# 17    102418  edcae211fcaaccf2cfd426f297ebd700
# 18    102419  edcba1bf22c77c87ed44ca2402d92efa
# 19    102420  edcc020b94ba865d7254269e6cdca99b
#
#                           categoria  ano_mes  valor_total estado
# 0   construction_tools_construction  2018-07        68.45     GO
# 1                         perfumery  2018-04       136.40     MG
# 2                     health_beauty  2018-07        61.58     MG
# 3                        cool_stuff  2018-01        42.58     SP
# 4                    sports_leisure  2017-05        30.86     SP
# 5                    bed_bath_table  2018-02        67.98     SP
# 6                              baby  2017-05       185.93     CE
# 7                        stationery  2018-08       133.42     RS
# 8          fashion_bags_accessories  2017-11        55.15     SP
# 9          fashion_bags_accessories  2017-11        73.00     SP
# 10         fashion_bags_accessories  2017-11        78.00     SP
# 11         fashion_bags_accessories  2017-11        80.15     SP
# 12                   sports_leisure  2017-07       144.67     RJ
# 13                 office_furniture  2017-04       140.03     RJ
# 14                             toys  2017-06       106.38     SP
# 15              musical_instruments  2018-03       365.13     RJ
# 16                    watches_gifts  2018-02        63.10     MG
# 17                   sports_leisure  2017-02      1367.50     SP
# 18                     garden_tools  2017-12        62.50     MG
# 19                    watches_gifts  2018-01       349.76     SP

# %%
banco_dados.sql("""
-- esta análise tem como objetivo identificar os 10 pedidos com maior valor total, juntamente com as informações do cliente e do estado de entrega. A consulta utiliza uma junção entre a tabela fato_vendas e a tabela dim_cliente para obter os detalhes do cliente, e ordena os resultados pelo valor total em ordem decrescente, limitando a exibição aos 10 primeiros registros.
SELECT
    v.venda_sk,
    v.order_id,
    v.cliente_sk,
    c.customer_city,
    c.customer_state,
    v.valor_total
FROM fato_vendas v
    LEFT JOIN dim_cliente c
ON v.cliente_sk = c.cliente_sk
    ORDER BY v.valor_total ASC
 LIMIT 10;
 """).df()
# Out:
#    venda_sk                          order_id  cliente_sk  customer_city  \
# 0     61577  8fbcb92faf1aa60361f61ed7ae721a7e       40877  teofilo otoni
# 1     61574  8fbcb92faf1aa60361f61ed7ae721a7e       40877  teofilo otoni
# 2     61573  8fbcb92faf1aa60361f61ed7ae721a7e       40877  teofilo otoni
# 3     61575  8fbcb92faf1aa60361f61ed7ae721a7e       40877  teofilo otoni
# 4     48999  71e22e2d99081d6dc07d9627bb85969e       69939      sao paulo
# 5     56044  8272b63d03f5f79c56e9e4120aec44ef       47121      sao paulo
# 6     56039  8272b63d03f5f79c56e9e4120aec44ef       47121      sao paulo
# 7     56042  8272b63d03f5f79c56e9e4120aec44ef       47121      sao paulo
# 8     56041  8272b63d03f5f79c56e9e4120aec44ef       47121      sao paulo
# 9     56043  8272b63d03f5f79c56e9e4120aec44ef       47121      sao paulo
#
#   customer_state  valor_total
# 0             MG         6.08
# 1             MG         6.08
# 2             MG         6.08
# 3             MG         6.08
# 4             SP         7.28
# 5             SP         9.09
# 6             SP         9.09
# 7             SP         9.09
# 8             SP         9.09
# 9             SP         9.09

# %% [markdown]
# # AULA 2 - SEMANA 9
#
# Agregação de tabelas:
# - GROUP_BY, COUNT, SUM e AVG
# - WHERE vs HAVING

# %% [markdown]
# #### Exemplo 1 (slide 18) - Faturamento por estado

# %%
banco_dados.sql("""
    SELECT
        c.customer_state AS estado,
        SUM(f.valor_total) AS faturamento_total,
        COUNT(f.order_id) AS qtd_pedidos,
        AVG(f.valor_total) AS valor_medio_item
    FROM fato_vendas f
    INNER JOIN dim_cliente c
        ON f.cliente_sk = c.cliente_sk
    GROUP BY c.customer_state
    ORDER BY faturamento_total DESC;
""").df()
# Out:
#    estado  faturamento_total  qtd_pedidos  valor_medio_item
# 0      SP         5769703.15        46448        124.218549
# 1      RJ         2055401.57        14143        145.329956
# 2      MG         1818891.67        12916        140.824688
# 3      RS          861472.79         6134        140.442255
# 4      PR          781708.80         5649        138.380032
# 5      SC          595127.78         4097        145.259404
# 6      BA          591137.81         3683        160.504428
# 7      DF          346123.35         2355        146.973822
# 8      GO          334212.35         2277        146.777492
# 9      ES          317657.93         2225        142.767609
# 10     PE          308972.05         1746        176.959937
# 11     CE          266436.77         1426        186.842055
# 12     PA          212023.57         1054        201.160882
# 13     MT          181224.42         1037        174.758361
# 14     MA          147803.55          800        184.754438
# 15     PB          137838.55          586        235.219369
# 16     MS          134367.55          811        165.681319
# 17     PI          105178.19          523        201.105526
# 18     RN          100714.78          521        193.310518
# 19     AL           94172.49          427        220.544473
# 20     SE           70289.13          375        187.437680
# 21     TO           60007.37          310        193.572161
# 22     RO           56966.00          273        208.666667
# 23     AM           27585.47          163        169.236012
# 24     AC           19575.33           91        215.113516
# 25     AP           16141.81           81        199.281605
# 26     RR            9039.52           46        196.511304

# %% [markdown]
# #### Exemplo 2 (slide 19) - Faturamento por categoria

# %%
banco_dados.sql("""
    SELECT
        p.product_category_name_english AS categoria,
        SUM(f.valor_total) AS faturamento_total,
        COUNT(*) AS qtd_itens,
        AVG(f.valor_total) AS ticket_medio
    FROM fato_vendas f
    INNER JOIN dim_produto p
        ON f.produto_sk = p.produto_sk
    GROUP BY p.product_category_name_english
    ORDER BY faturamento_total DESC;
 """).df()
# Out:
#                     categoria  faturamento_total  qtd_itens  ticket_medio
# 0               health_beauty         1412089.53       9465    149.190653
# 1               watches_gifts         1264333.12       5859    215.793330
# 2              bed_bath_table         1225209.26      10953    111.860610
# 3              sports_leisure         1118256.91       8431    132.636331
# 4       computers_accessories         1032723.77       7644    135.102534
# ..                        ...                ...        ...           ...
# 67                    flowers            1598.91         33     48.451818
# 68             home_comfort_2            1170.58         30     39.019333
# 69          cds_dvds_musicals             954.99         14     68.213571
# 70  fashion_childrens_clothes             598.67          7     85.524286
# 71      security_and_services             324.51          2    162.255000
#
# [72 rows x 4 columns]

# %% [markdown]
# ### EXERCÍCIO (SLIDE 20) - Métricas por mês

# %%
banco_dados.sql("""
-- SUA CONSULTA AQUI
""").df()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 3
#       1 banco_dados.sql("""
#       2 -- SUA CONSULTA AQUI
# ----> 3 """).df()
#
# AttributeError: 'NoneType' object has no attribute 'df'

# %% [markdown]
# # SLIDE 23

# %%
banco_dados.sql("""
    SELECT
        c.customer_state AS estado,
        SUM(f.valor_total) AS receita_total
    FROM fato_vendas f
    INNER JOIN dim_cliente c    
        ON f.cliente_sk = c.cliente_sk
    GROUP BY c.customer_state
    HAVING receita_total > 100000
    ORDER BY receita_total DESC;                              
""").df()
# Out:
#    estado  receita_total
# 0      SP     5769703.15
# 1      RJ     2055401.57
# 2      MG     1818891.67
# 3      RS      861472.79
# 4      PR      781708.80
# 5      SC      595127.78
# 6      BA      591137.81
# 7      DF      346123.35
# 8      GO      334212.35
# 9      ES      317657.93
# 10     PE      308972.05
# 11     CE      266436.77
# 12     PA      212023.57
# 13     MT      181224.42
# 14     MA      147803.55
# 15     PB      137838.55
# 16     MS      134367.55
# 17     PI      105178.19
# 18     RN      100714.78

# %% [markdown]
# ## Exercício 16  — Faturamento por estado
#
# Retorne o valor_total por estado
# Dica: use as funções SUM, COUNT, AVG, GROUP_BY e ORDER_BY e JOIN

# %%
## Resposta exercício 16

banco_dados.sql("""
    SELECT
        c.customer_state AS estado,
        SUM(f.valor_total) AS receita_total,
        COUNT(f.venda_sk) AS qtd_vendas,
        AVG(f.valor_total) AS ticket_medio
    FROM fato_vendas f
    INNER JOIN dim_cliente c
        ON f.cliente_sk = c.cliente_sk
    GROUP BY c.customer_state
    ORDER BY receita_total DESC;                   
""").df()
# Out:
#    estado  receita_total  qtd_vendas  ticket_medio
# 0      SP     5769703.15       46448    124.218549
# 1      RJ     2055401.57       14143    145.329956
# 2      MG     1818891.67       12916    140.824688
# 3      RS      861472.79        6134    140.442255
# 4      PR      781708.80        5649    138.380032
# 5      SC      595127.78        4097    145.259404
# 6      BA      591137.81        3683    160.504428
# 7      DF      346123.35        2355    146.973822
# 8      GO      334212.35        2277    146.777492
# 9      ES      317657.93        2225    142.767609
# 10     PE      308972.05        1746    176.959937
# 11     CE      266436.77        1426    186.842055
# 12     PA      212023.57        1054    201.160882
# 13     MT      181224.42        1037    174.758361
# 14     MA      147803.55         800    184.754437
# 15     PB      137838.55         586    235.219369
# 16     MS      134367.55         811    165.681319
# 17     PI      105178.19         523    201.105526
# 18     RN      100714.78         521    193.310518
# 19     AL       94172.49         427    220.544473
# 20     SE       70289.13         375    187.437680
# 21     TO       60007.37         310    193.572161
# 22     RO       56966.00         273    208.666667
# 23     AM       27585.47         163    169.236012
# 24     AC       19575.33          91    215.113516
# 25     AP       16141.81          81    199.281605
# 26     RR        9039.52          46    196.511304

# %% [markdown]
# ## Exercício 17 — Top 10 categorias
#
# Retorne uma tabela que mostre as top 10 categorias de maior faturamento total

# %%
print(dim_produto.columns)
# Out:
# Index(['produto_sk', 'product_id', 'product_category_name',
#        'product_category_name_english'],
#       dtype='str')

# %%
## Resposta exercício 17

banco_dados.sql("""
    SELECT
        p.product_category_name AS categoria,
        SUM(f.valor_total) AS faturamento
    FROM fato_vendas f
    INNER JOIN dim_produto p
        ON f.produto_sk = p.produto_sk
    GROUP BY categoria
    ORDER BY faturamento DESC
    LIMIT 10;
""").df()
# Out:
#                 categoria  faturamento
# 0            beleza_saude   1412089.53
# 1      relogios_presentes   1264333.12
# 2         cama_mesa_banho   1225209.26
# 3           esporte_lazer   1118256.91
# 4  informatica_acessorios   1032723.77
# 5        moveis_decoracao    880329.92
# 6   utilidades_domesticas    758392.25
# 7              cool_stuff    691680.89
# 8              automotivo    669454.75
# 9      ferramentas_jardim    567145.68

# %% [markdown]
# ## Exercício 18 (Aula 2 semana 9) — Os 5 estados com maior ticket médio
#
# Retorne uma tabela que mostre o ticket médio por estado
# Dica: Use a função COUNT, SUM, AVG e HAVING

# %%
print(dim_cliente.columns)
print(fato_vendas.columns)
# Out:
# Index(['cliente_sk', 'customer_id', 'customer_unique_id', 'customer_city',
#        'customer_state'],
#       dtype='str')
# Index(['venda_sk', 'order_id', 'order_item_id', 'cliente_sk', 'produto_sk',
#        'tempo_sk', 'valor_produto', 'valor_frete', 'valor_total'],
#       dtype='str')

# %%
## Resposta exercício 18

banco_dados.sql("""
    SELECT
        c.customer_state as estado,
        COUNT(f.venda_sk) as qtde_vendas,
        SUM(f.valor_total) as faturamento,
        AVG(f.valor_total) as ticket_medio
    FROM fato_vendas f
    INNER JOIN dim_cliente c
        ON f.cliente_sk = c.cliente_sk
    GROUP BY estado
    ORDER BY ticket_medio DESC
    LIMIT 5;
""").df()
# Out:
#   estado  qtde_vendas  faturamento  ticket_medio
# 0     PB          586    137838.55    235.219369
# 1     AL          427     94172.49    220.544473
# 2     AC           91     19575.33    215.113516
# 3     RO          273     56966.00    208.666667
# 4     PA         1054    212023.57    201.160882

# %% [markdown]
# ## Exercício 19 (Aula 2 semana 9) — Evolução mensal de faturamento
#
# Use função SUM, GROUP_BY, ORDER_BY E JOIN

# %%
print(dim_tempo.columns)
# Out:
# Index(['tempo_sk', 'data', 'ano', 'mes', 'dia', 'trimestre', 'ano_mes'], dtype='str')

# %%
### Resposta exercício 19

banco_dados.sql("""
   SELECT
        t.ano as ano,
        t.mes as mes,
        SUM(f.valor_total) as faturamento,
    FROM fato_vendas f
    INNER JOIN dim_tempo t
        ON f.tempo_sk = t.tempo_sk
    GROUP BY ano, mes
    ORDER BY ano, mes;
""").df()
# Out:
#      ano  mes  faturamento
# 0   2016    9       143.46
# 1   2016   10     46490.66
# 2   2016   12        19.62
# 3   2017    1    127482.37
# 4   2017    2    271239.32
# 5   2017    3    414330.95
# 6   2017    4    390812.40
# 7   2017    5    566851.40
# 8   2017    6    490050.37
# 9   2017    7    566299.08
# 10  2017    8    645832.36
# 11  2017    9    701077.49
# 12  2017   10    751117.01
# 13  2017   11   1153364.20
# 14  2017   12    843078.29
# 15  2018    1   1077887.46
# 16  2018    2    966168.41
# 17  2018    3   1120598.24
# 18  2018    4   1132878.93
# 19  2018    5   1128774.52
# 20  2018    6   1011978.29
# 21  2018    7   1027807.28
# 22  2018    8    985491.64

# %% [markdown]
# ### EXERCÍCIOS SLIDE 27: PRATIQUE FILTROS DE GRUPO

# %% [markdown]
# #### Pedidos por estado
#
# Enunciado: Liste os estados com mais de 500 pedidos únicos. Ordene do maior para o menor volume

# %%
print(dim_cliente.columns)
print(fato_vendas.columns)
# Out:
# Index(['cliente_sk', 'customer_id', 'customer_unique_id', 'customer_city',
#        'customer_state'],
#       dtype='str')
# Index(['venda_sk', 'order_id', 'order_item_id', 'cliente_sk', 'produto_sk',
#        'tempo_sk', 'valor_produto', 'valor_frete', 'valor_total'],
#       dtype='str')

# %%
banco_dados.sql("""
   SELECT
        c.customer_state as estado,
        COUNT(DISTINCT f.order_id) as pedidos_unicos,
    FROM fato_vendas f
    INNER JOIN dim_cliente c
        ON f.cliente_sk = c.cliente_sk
    GROUP BY estado
    HAVING pedidos_unicos >=500                
    ORDER BY pedidos_unicos DESC;
""").df()
# Out:
#    estado  pedidos_unicos
# 0      SP           40501
# 1      RJ           12350
# 2      MG           11354
# 3      RS            5345
# 4      PR            4923
# 5      SC            3546
# 6      BA            3256
# 7      DF            2080
# 8      ES            1995
# 9      GO            1957
# 10     PE            1593
# 11     CE            1279
# 12     PA             946
# 13     MT             886
# 14     MA             717
# 15     MS             701
# 16     PB             517

# %% [markdown]
# #### Receita por categoria
#
# Enunciado: Liste as categorias com receita total acima de R$ 50.000. Ordene pela receita.

# %%
print(dim_produto.columns)
# Out:
# Index(['produto_sk', 'product_id', 'product_category_name',
#        'product_category_name_english'],
#       dtype='str')

# %%
banco_dados.sql("""
   SELECT
        p.product_category_name AS categoria,
        SUM(f.valor_total) AS receita_total
    FROM fato_vendas f
    INNER JOIN dim_produto p
        ON f.produto_sk = p.produto_sk
    GROUP BY categoria
    HAVING receita_total >= 50000
    ORDER BY receita_total DESC;
""").df()
# Out:
#                                          categoria  receita_total
# 0                                     beleza_saude     1412089.53
# 1                               relogios_presentes     1264333.12
# 2                                  cama_mesa_banho     1225209.26
# 3                                    esporte_lazer     1118256.91
# 4                           informatica_acessorios     1032723.77
# 5                                 moveis_decoracao      880329.92
# 6                            utilidades_domesticas      758392.25
# 7                                       cool_stuff      691680.89
# 8                                       automotivo      669454.75
# 9                               ferramentas_jardim      567145.68
# 10                                      brinquedos      547061.06
# 11                                           bebes      466727.65
# 12                                      perfumaria      443171.63
# 13                                       telefonia      379202.62
# 14                               moveis_escritorio      335211.36
# 15                                       papelaria      269575.05
# 16                                        pet_shop      250614.20
# 17                                             pcs      228349.76
# 18                           instrumentos_musicais      202187.12
# 19                                     eletronicos      200723.09
# 20                                 eletroportateis      198108.47
# 21                                             NaN      197695.69
# 22                     fashion_bolsas_e_acessorios      179888.29
# 23                                malas_acessorios      168778.12
# 24                                  consoles_games      167097.73
# 25               construcao_ferramentas_construcao      162382.01
# 26                              eletrodomesticos_2      118208.52
# 27                                 casa_construcao       95022.37
# 28                                eletrodomesticos       93301.78
# 29                                     moveis_sala       85045.07
# 30                       agro_industria_e_comercio       76203.30
# 31                                   casa_conforto       66438.22
# 32                                    climatizacao       59854.55
# 33                                  telefonia_fixa       59816.54
# 34  moveis_cozinha_area_de_servico_jantar_e_jardim       57072.97
# 35                                           audio       56255.32
# 36                          livros_interesse_geral       54182.54

# %% [markdown]
# #### Ticket médio por categoria
#
# Enunciado: Use categoria como grupo e mostre apenas categorias com ticket médio acima de R$ 100.

# %%
banco_dados.sql("""
   SELECT
        p.product_category_name AS categoria,
        AVG(f.valor_total) AS ticket_medio
    FROM fato_vendas f
    INNER JOIN dim_produto p
        ON f.produto_sk = p.produto_sk
    GROUP BY categoria
    HAVING ticket_medio > 100
    ORDER BY ticket_medio DESC;
""").df()
# Out:
#                                          categoria  ticket_medio
# 0                                              pcs   1147.486231
# 1                      portateis_casa_forno_e_cafe    674.601370
# 2                               eletrodomesticos_2    511.725195
# 3                        agro_industria_e_comercio    369.918932
# 4                            instrumentos_musicais    310.579293
# 5    portateis_cozinha_e_preparadores_de_alimentos    302.003571
# 6                                  eletroportateis    301.076702
# 7                                   telefonia_fixa    234.574667
# 8                 construcao_ferramentas_seguranca    232.262404
# 9                                    moveis_quarto    226.982718
# 10                              relogios_presentes    215.793330
# 11  moveis_cozinha_area_de_servico_jantar_e_jardim    208.295511
# 12                                    climatizacao    207.109170
# 13                               moveis_escritorio    200.966043
# 14                                      cool_stuff    186.035742
# 15                                        pc_gamer    178.762500
# 16               construcao_ferramentas_construcao    177.272937
# 17                                          musica    176.970000
# 18              construcao_ferramentas_ferramentas    174.118155
# 19                   industria_comercio_e_negocios    173.884302
# 20                                     moveis_sala    171.808222
# 21                                      la_cuisine    170.610000
# 22                              seguros_e_servicos    162.255000
# 23                                      automotivo    161.704046
# 24                       moveis_colchao_e_estofado    159.587838
# 25                                 casa_construcao    159.433507
# 26               construcao_ferramentas_iluminacao    157.631694
# 27                                malas_acessorios    156.711346
# 28                                           bebes    156.514973
# 29                                           audio    155.401436
# 30                                   casa_conforto    154.867646
# 31                                  consoles_games    153.441442
# 32                                    beleza_saude    149.190653
# 33                         sinalizacao_e_seguranca    141.079137
# 34                                           artes    139.520457
# 35                                      brinquedos    135.747161
# 36                          informatica_acessorios    135.102534
# 37                              ferramentas_jardim    132.883243
# 38                                      perfumaria    132.686117
# 39                                   esporte_lazer    132.636331
# 40                   construcao_ferramentas_jardim    130.534224
# 41                                        pet_shop    130.256861
# 42                                             NaN    128.624392
# 43                               artigos_de_festas    125.842381
# 44                                eletrodomesticos    123.742414
# 45                                       cine_foto    112.888286
# 46                                 cama_mesa_banho    111.860610
# 47                           utilidades_domesticas    111.610338
# 48                                       papelaria    109.316727
# 49                                    market_place    108.571738
# 50                                fashion_calcados    108.228911
# 51                                moveis_decoracao    107.883569
# 52                        tablets_impressao_imagem    105.477229
# 53                          livros_interesse_geral    100.898585
# 54                         fashion_roupa_masculina    100.119600

# %% [markdown]
# # AULA 3 - SEMANA 9
# - DATE_TRUNC
# - EXTRACT

# %% [markdown]
# ### SLIDE 32: Transformando datas em período

# %%
banco_dados.sql("""
-- Conversão para data no SQL
    SELECT CAST(t.data AS DATE) AS data_pedido
        FROM dim_tempo t
        LIMIT 5
""").df()
# Out:
#   data_pedido
# 0  2017-10-02
# 1  2018-07-24
# 2  2018-08-08
# 3  2017-11-18
# 4  2018-02-13

# %%
banco_dados.sql("""
-- Agrupamento no início do mês
    SELECT 
        DATE_TRUNC('month', CAST(t.data AS DATE)) AS mes_referencia
        FROM dim_tempo t
        LIMIT 5
""").df()
# Out:
#   mes_referencia
# 0     2017-10-01
# 1     2018-07-01
# 2     2018-08-01
# 3     2017-11-01
# 4     2018-02-01

# %% [markdown]
# ### Slide 33 - EXTRACT: Conceito e Sintaxe
# Extraindo partes da data

# %%
banco_dados.sql("""
SELECT
    CAST(t.data AS DATE) AS data_pedido,
    EXTRACT(YEAR FROM CAST(t.data AS DATE)) AS ano,
    EXTRACT(MONTH FROM CAST(t.data AS DATE)) AS mes,
    EXTRACT(QUARTER FROM CAST(t.data AS DATE)) AS trimestre,
    FROM dim_tempo t
    LIMIT 10
""").df()
# Out:
#   data_pedido   ano  mes  trimestre
# 0  2017-10-02  2017   10          4
# 1  2018-07-24  2018    7          3
# 2  2018-08-08  2018    8          3
# 3  2017-11-18  2017   11          4
# 4  2018-02-13  2018    2          1
# 5  2017-07-09  2017    7          3
# 6  2017-05-16  2017    5          2
# 7  2017-01-23  2017    1          1
# 8  2017-07-29  2017    7          3
# 9  2017-07-13  2017    7          3

# %% [markdown]
# ### SLIDE 34 EXTRACT: Totais por Ano e Análise de Sazonalidade
# Receita por ano e sazonalidade por mês

# %%
banco_dados.sql("""
    SELECT
        EXTRACT(YEAR FROM CAST(t.data AS DATE)) AS ano,
        COUNT(f.order_id) AS qtd_pedidos,
        SUM(f.valor_total) AS receita_anual
    FROM fato_vendas f
    INNER JOIN dim_tempo t
        ON f.tempo_sk = t.tempo_sk
    GROUP BY EXTRACT(YEAR FROM CAST(t.data AS DATE))
    ORDER BY ano ASC;
""").df()
# Out:
#     ano  qtd_pedidos  receita_anual
# 0  2016          317       46653.74
# 1  2017        49556     6921535.24
# 2  2018        60324     8451584.77

# %% [markdown]
# ### Sazonalidade por mês

# %%
banco_dados.sql("""
-- Sazonalidade por mês   
    SELECT
        EXTRACT(MONTH FROM CAST(t.data AS DATE)) AS mes,
        COUNT(f.order_id) AS qtd_pedidos,
        SUM(f.valor_total) AS receita_mensal
    FROM fato_vendas f
    INNER JOIN dim_tempo t
        ON f.tempo_sk = t.tempo_sk
    GROUP BY 1 -- agrupa pelo número da coluna mes
    ORDER BY mes ASC;
""").df()
# Out:
#     mes  qtd_pedidos  receita_mensal
# 0     1         8950      1205369.83
# 1     2         9376      1237407.73
# 2     3        10914      1534929.19
# 3     4        10396      1523691.33
# 4     5        11814      1695625.92
# 5     6        10499      1502028.66
# 6     7        11379      1594106.36
# 7     8        11939      1631324.00
# 8     9         4740       701220.95
# 9    10         5527       797607.67
# 10   11         8475      1153364.20
# 11   12         6188       843097.91
